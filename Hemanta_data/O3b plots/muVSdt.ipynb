# %%
import numpy as np
import matplotlib.pyplot as plt
# libraries & dataset
import seaborn as sns
import json
# %matplotlib inline

# %%
mu_all = []
dt_all = []
snr_all = []
for i in range(10):
    path = './detectable_4_image_type_any/batch'+str(i+1)+'.json'
    f = open (path, "r")
    param = json.loads(f.read())
    mu_all += param['magnifications']
    dt_all += param['time_delays']
    snr_all += param['opt_snr_net']
mu_all = np.array(mu_all)
dt_all = np.array(dt_all)
snr_all = np.array(snr_all)

# %% [markdown]
# # $\Delta \phi = 0$

# %% [markdown]
# ## TypeI

# %%
mu1 = []
mu2 = []
dt1 = []
dt2 = []
for i in range(len(mu_all)):
    if snr_all[i,0]>8. and snr_all[i,1]>8.:
        mu1.append(snr_all[i,0])
        mu2.append(snr_all[i,1])
        dt1.append(dt_all[i,0])
        dt2.append(dt_all[i,1])
        
mu1 = np.array(mu1)
mu2 = np.array(mu2)
dt1 = np.array(dt1)
dt2 = np.array(dt2)

# relative magnification
dmu12 = abs(mu2/mu1)
# relative time delays
dt12 = abs(dt2-dt1)

# %% [markdown]
# # typeII

# %%
mu3 = []
mu4 = []
dt3 = []
dt4 = []
for i in range(len(mu_all)):
    if snr_all[i,2]>8. and snr_all[i,3]>8.:
        mu3.append(snr_all[i,2])
        mu4.append(snr_all[i,3])
        dt3.append(dt_all[i,2])
        dt4.append(dt_all[i,3])
        
mu3 = np.array(mu3)
mu4 = np.array(mu4)
dt3 = np.array(dt3)
dt4 = np.array(dt4)

# relative magnification
dmu34 = abs(mu4/mu3)
# relative time delays
dt34 = abs(dt4-dt3)

# %%
dmu1 = np.concatenate((dmu12,dmu34))
dt1 = np.concatenate((dt12,dt34))/(60*60*24) # to days

# %%
df = sns.load_dataset('iris')
 
# set seaborn style
sns.set_style("white")

# Basic 2D density plot
x = np.log10(dt1)
y = np.log(dmu1)
sns.kdeplot(x=x, y=y,legend=True, levels=1,thresh=.68)
sns.kdeplot(x=x, y=y,legend=True, levels=1,thresh=.95)
sns.kdeplot(x=x, y=y,legend=True, levels=1,thresh=.997)
#plt.xlim(-2, 3)
#plt.ylim(-2, 2)
plt.xlabel(r'$log(abs(\Delta t_{21}))\,days$')
plt.ylabel(r'$log10(\mu_2/\mu_1)$')
plt.title('relative time delay vs relative magnification \n Image type I')
plt.legend()
plt.grid()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df = sns.load_dataset('iris')
 
# set seaborn style
sns.set_style("white")

# Basic 2D density plot
x = np.log10(dt1)
y = np.log(dmu1)
sns.kdeplot(x=x, y=y,legend=True, cut=0,thresh=0)
plt.xlabel(r'$log(abs(\Delta t))\,days$')
plt.ylabel(r'$log10(\mu_2/\mu_1)$')
plt.title('relative time delay vs relative magnification \n Image type I')
plt.legend()
plt.grid()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
dict_ = {'dmu': dmu1.tolist(), 'dt': dt1.tolist()}

file_name = './phase_diff_0.json'
json_dump = json.dumps(dict_)
with open(file_name, "w") as write_file:
    json.dump(json.loads(json_dump), write_file, indent=4)

# %% [markdown]
# # $\Delta \phi = 90$

# %%
mu1 = []
mu3 = []
dt1 = []
dt3 = []
for i in range(len(mu_all)):
    if snr_all[i,0]>8. and snr_all[i,2]>8.:
        mu1.append(snr_all[i,0])
        mu3.append(snr_all[i,2])
        dt1.append(dt_all[i,0])
        dt3.append(dt_all[i,2])
        
mu1 = np.array(mu1)
mu3 = np.array(mu3)
dt1 = np.array(dt1)
dt3 = np.array(dt3)

# relative magnification
dmu13 = abs(mu3/mu1)
# relative time delays
dt13 = abs(dt3-dt1)

# %%
mu2 = []
mu4 = []
dt2 = []
dt4 = []
for i in range(len(mu_all)):
    if snr_all[i,1]>8. and snr_all[i,3]>8.:
        mu2.append(snr_all[i,1])
        mu4.append(snr_all[i,3])
        dt2.append(dt_all[i,1])
        dt4.append(dt_all[i,3])
        
mu2 = np.array(mu2)
mu4 = np.array(mu4)
dt2 = np.array(dt2)
dt4 = np.array(dt4)

# relative magnification
dmu24 = abs(mu4/mu2)
# relative time delays
dt24 = abs(dt4-dt2)

# %%
mu1 = []
mu4 = []
dt1 = []
dt4 = []
for i in range(len(mu_all)):
    if snr_all[i,0]>8. and snr_all[i,3]>8.:
        mu1.append(snr_all[i,0])
        mu4.append(snr_all[i,3])
        dt1.append(dt_all[i,0])
        dt4.append(dt_all[i,3])
        
mu1 = np.array(mu1)
mu4 = np.array(mu4)
dt1 = np.array(dt1)
dt4 = np.array(dt4)

# relative magnification
dmu14 = abs(mu4/mu1)
# relative time delays
dt14 = abs(dt4-dt1)

# %%
mu2 = []
mu3 = []
dt2 = []
dt3 = []
for i in range(len(mu_all)):
    if snr_all[i,1]>8. and snr_all[i,2]>8.:
        mu2.append(snr_all[i,1])
        mu3.append(snr_all[i,2])
        dt2.append(dt_all[i,1])
        dt3.append(dt_all[i,2])
        
mu2 = np.array(mu2)
mu3 = np.array(mu3)
dt2 = np.array(dt2)
dt3 = np.array(dt3)

# relative magnification
dmu23 = abs(mu3/mu2)
# relative time delays
dt23 = abs(dt3-dt2)

# %%
dmu2 = np.concatenate((dmu13,dmu24,dmu14,dmu23))
dt2 = np.concatenate((dt13,dt24,dt14,dt23))/(60*60*24) # to days

# %%
df = sns.load_dataset('iris')
 
# set seaborn style
sns.set_style("white")

# Basic 2D density plot
x = np.log10(dt2)
y = np.log10(dmu2)
sns.kdeplot(x=x, y=y,legend=True, levels=1,thresh=.68)
sns.kdeplot(x=x, y=y,legend=True, levels=1,thresh=.95)
sns.kdeplot(x=x, y=y,legend=True, levels=1,thresh=.997)
#plt.xlim(-2, 3)
#plt.ylim(-2, 2)
plt.xlabel(r'$log(abs(\Delta t_{21}))\,days$')
plt.ylabel(r'$log10(\mu_2/\mu_1)$')
plt.title('relative time delay vs relative magnification \n Image type I')
plt.legend()
plt.grid()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df = sns.load_dataset('iris')
 
# set seaborn style
sns.set_style("white")

# Basic 2D density plot
x = np.log10(dt2)
y = np.log10(dmu2)
sns.kdeplot(x=x, y=y,legend=True, cut=0,thresh=0)
plt.xlabel(r'$log(abs(\Delta t))\,days$')
plt.ylabel(r'$log10(\mu_2/\mu_1)$')
plt.title('relative time delay vs relative magnification \n Image type I')
plt.legend()
plt.grid()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
dict_ = {'dmu': dmu2.tolist(), 'dt': dt2.tolist()}

file_name = './phase_diff_90.json'
json_dump = json.dumps(dict_)
with open(file_name, "w") as write_file:
    json.dump(json.loads(json_dump), write_file, indent=4)
